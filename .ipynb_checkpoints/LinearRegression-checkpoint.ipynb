# %% [markdown]
# # import libraries

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import linear_model,model_selection
from sklearn.model_selection import train_test_split

# %% [markdown]
# # import dataset

# %%
dataset = pd.read_csv('adm_data.csv')

# %% [markdown]
# # Look dataset

# %%
dataset
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %% [markdown]
# # In ra các column của dataset

# %%
dataset.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# # Kiểm tra thông tin dataset có cột nào null không, có

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %% [markdown]
# # Kiểm tra cột nào có giá trị null

# %%
dataset.isnull().sum()
dataset['Research'].value_counts()
# Out:
# 1    219
# 0    181
# Name: Research, dtype: int64

# %% [markdown]
# # Kiểm tra mối liên hệ giữa các biến với nhau

# %%
dataset.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# TOEFL Score        0.657981  0.567721  0.828417  0.489858          0.791594
# University Rating  0.734523  0.660123  0.746479  0.447783          0.711250
# SOP                1.000000  0.729593  0.718144  0.444029          0.675732
# LOR                0.729593  1.000000  0.670211  0.396859          0.669889
# CGPA               0.718144  0.670211  1.000000  0.521654          0.873289
# Research           0.444029  0.396859  0.521654  1.000000          0.553202
# Chance of Admit    0.675732  0.669889  0.873289  0.553202          1.000000

# %% [markdown]
# # Trực quan hóa mối liên hệ giữa các biến với nhau

# %%
plt.figure(figsize=(10,7))
sns.heatmap(dataset.corr(),annot=True,cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# # Trực quan hóa từng column của dataset dưới dạng đồ thị cột

# %%
dataset.hist(bins=50,figsize=(15,20))
plt.show()

# %% [markdown]
# # Tạo feature và label cho linear regression model

# %%
feature = dataset[['GRE Score', 'TOEFL Score', 'University Rating', 'SOP','LOR ', 'CGPA', 'Research']]
label = dataset['Chance of Admit ']

# %% [markdown]
# # Tạo data train và test model

# %%
dataX_train,dataX_test,dataY_train,dataY_test = train_test_split(feature,label,test_size=1/3, random_state=0)

# %% [markdown]
# # Tạo linear regression model và train model

# %%
linear_regression = linear_model.LinearRegression()
linear_regression.fit(dataX_train,dataY_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Tìm ma trận weight và giá trị b trong linear regression model

# %%
b = linear_regression.intercept_
w = linear_regression.coef_
w,b
# Out:
# (array([0.00195021, 0.00208481, 0.00199112, 0.00041616, 0.017307  ,
#         0.13262225, 0.01816356]),
#  -1.335869556749909)

# %% [markdown]
# # Test model

# %%
linear_regression.predict([[0,0,0,0,0,0,0]])
# Out:
# C:\Users\TanLoc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-1.33586956])

# %%
b + np.dot(w,[337,118,4,4.5,4.5,9.65,1])
# Out:
# 0.9530468617563006

# %%
linear_regression.score(feature,label)
# Out:
# 0.8017937035812226

# %% [markdown]
# # Thêm cột Mô hình dự đoán và cột loss

# %%
dataset['Chance of Admit Predict'] = linear_regression.predict(feature)
dataset['loss'] = abs(dataset['Chance of Admit '] - dataset['Chance of Admit Predict'])
dataset
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit   Chance of Admit Predict      loss
# 0           1              0.92                 0.953047  0.033047
# 1           1              0.76                 0.801108  0.041108
# 2           1              0.72                 0.644156  0.075844
# 3           1              0.80                 0.740124  0.059876
# 4           0              0.65                 0.636797  0.013203
# ..        ...               ...                      ...       ...
# 395         1              0.82                 0.810402  0.009598
# 396         1              0.84                 0.815173  0.024827
# 397         1              0.91                 0.908909  0.001091
# 398         0              0.67                 0.728414  0.058414
# 399         1              0.95                 0.936042  0.013958
#
# [400 rows x 11 columns]

# %%
feature = dataset[['GRE Score', 'TOEFL Score', 'University Rating', 'SOP','LOR ', 'CGPA', 'Research']]
label = dataset['Chance of Admit ']
dataX_train,dataX_test,dataY_train,dataY_test = train_test_split(feature,label,test_size=1/3, random_state=0)
linear_regression.fit(dataX_train,dataY_train)
linear_regression.score(feature,label)
# Out:
# 0.8017937035812226

# %%
import sys
from PyQt5 import QtWidgets, uic

class Gui():
    def __init__(self):
        self.main_win = QtWidgets.QMainWindow()
        self.ui = uic.loadUi('main.ui',self.main_win)
        self.ui.predict.clicked.connect(self.clicked)
    def show(self):
        self.main_win.show()
        
    def clicked(self):
        result = linear_regression.predict([[int(self.ui.GRE_Score.toPlainText()),int(self.ui.TOEFL_Score.toPlainText()),int(self.ui.rate.currentText()),float(self.ui.SOP.currentText()),float(self.ui.LOR.currentText()),float(self.ui.CGPA.toPlainText()),int(self.ui.research.currentText())]])
        self.ui.view.setText("Chance of Admit Predict: "+str(result)[1:-1])
app = QtWidgets.QApplication(sys.argv)
f1 = Gui()
f1.show()
app.exec()
# Out:
# C:\Users\TanLoc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 0
